# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df = pd.read_excel(r"C:\Users\Hp\Downloads\Practice Data frames\Netflix_Dataset.xlsx")

# %%
df.head(3)
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2     The Con-Heartist                         Comedy, Romance
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2  Romantic Comedies,Comedies,Romantic Films,Thai...              Thai
#
#   Series or Movie  Hidden Gem Score Country Availability       Runtime  \
# 0          Series               4.3             Thailand  < 30 minutes
# 1           Movie               7.0               Canada      1-2 hour
# 2           Movie               8.6             Thailand       > 2 hrs
#
#           Director                                             Writer  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# Title                       0
# Genre                      25
# Tags                       36
# Languages                 170
# Series or Movie             0
# Hidden Gem Score           10
# Country Availability       11
# Runtime                     1
# Director                 2305
# Writer                   1810
# Actors                    111
# View Rating              2598
# IMDb Score                  8
# Rotten Tomatoes Score    3980
# Metacritic Score         5343
# Awards Received          4199
# Awards Nominated For     3049
# Boxoffice                5671
# Release Date              208
# Netflix Release Date        0
# Production House         5032
# Netflix Link                0
# IMDb Link                 324
# Summary                     5
# IMDb Votes                 10
# Image                       0
# Poster                    938
# TMDb Trailer                0
# Trailer Site                1
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Netflix Link', 'IMDb Link',
#        'Summary', 'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer',
#        'Trailer Site'],
#       dtype='object')

# %%
df.drop(['Tags','Release Date','View Rating','Metacritic Score','Boxoffice','Netflix Link', 'IMDb Link',
       'Summary', 'Image', 'Poster', 'TMDb Trailer','Trailer Site','Release Date',
       ],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Languages', 'Series or Movie', 'Hidden Gem Score',
#        'Country Availability', 'Runtime', 'Director', 'Writer', 'Actors',
#        'IMDb Score', 'Rotten Tomatoes Score', 'Awards Received',
#        'Awards Nominated For', 'Netflix Release Date', 'Production House',
#        'IMDb Votes'],
#       dtype='object')

# %%
df.isnull().sum()*100/len(df)
# Out:
# Title                     0.000000
# Genre                     0.265252
# Languages                 1.803714
# Series or Movie           0.000000
# Hidden Gem Score          0.106101
# Country Availability      0.116711
# Runtime                   0.010610
# Director                 24.456233
# Writer                   19.204244
# Actors                    1.177719
# IMDb Score                0.084881
# Rotten Tomatoes Score    42.228117
# Awards Received          44.551724
# Awards Nominated For     32.350133
# Netflix Release Date      0.000000
# Production House         53.389920
# IMDb Votes                0.106101
# dtype: float64

# %%
a = df.isnull().sum()*100/len(df)
a.sort_values(ascending = False)
# Out:
# Production House         53.389920
# Awards Received          44.551724
# Rotten Tomatoes Score    42.228117
# Awards Nominated For     32.350133
# Director                 24.456233
# Writer                   19.204244
# Languages                 1.803714
# Actors                    1.177719
# Genre                     0.265252
# Country Availability      0.116711
# IMDb Votes                0.106101
# Hidden Gem Score          0.106101
# IMDb Score                0.084881
# Runtime                   0.010610
# Netflix Release Date      0.000000
# Series or Movie           0.000000
# Title                     0.000000
# dtype: float64

# %%
df.isnull().sum().sum()
# Out:
# 20721

# %%
df.shape
# Out:
# (9425, 17)

# %%
df['Director'].dropna(inplace=True)
df['Writer'].dropna(inplace=True)
df['Languages'].dropna(inplace=True)
df['Actors'].dropna(inplace=True)
df['Country Availability'].dropna(inplace=True)
df['Genre'].dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Title                       0
# Genre                      25
# Languages                 170
# Series or Movie             0
# Hidden Gem Score           10
# Country Availability       11
# Runtime                     1
# Director                 2305
# Writer                   1810
# Actors                    111
# IMDb Score                  8
# Rotten Tomatoes Score    3980
# Awards Received          4199
# Awards Nominated For     3049
# Netflix Release Date        0
# Production House         5032
# IMDb Votes                 10
# dtype: int64

# %%
df.dropna(subset=['Director'], inplace = True)
df.dropna(subset=['Country Availability'], inplace = True)
df.dropna(subset=['Actors'], inplace = True)
df.dropna(subset=['Languages'], inplace = True)
df.dropna(subset=['Writer'], inplace = True)

# %%
df.isnull().sum()
# Out:
# Title                       0
# Genre                       1
# Languages                   0
# Series or Movie             0
# Hidden Gem Score            3
# Country Availability        0
# Runtime                     0
# Director                    0
# Writer                      0
# Actors                      0
# IMDb Score                  3
# Rotten Tomatoes Score    1420
# Awards Received          2524
# Awards Nominated For     1674
# Netflix Release Date        0
# Production House         2398
# IMDb Votes                  3
# dtype: int64

# %%
df['Hidden Gem Score'].ffill(axis = 0, inplace = True)
df['IMDb Score'].bfill(axis = 0, inplace = True)
df['IMDb Votes']  = df['IMDb Votes'].fillna(df['IMDb Votes'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Title                       0
# Genre                       1
# Languages                   0
# Series or Movie             0
# Hidden Gem Score            0
# Country Availability        0
# Runtime                     0
# Director                    0
# Writer                      0
# Actors                      0
# IMDb Score                  0
# Rotten Tomatoes Score    1420
# Awards Received          2524
# Awards Nominated For     1674
# Netflix Release Date        0
# Production House         2398
# IMDb Votes                  0
# dtype: int64

# %%
df['Rotten Tomatoes Score'].fillna(df['Rotten Tomatoes Score'].mean(), inplace = True)

# %%
df['Awards Received'] = df['Awards Received'].fillna(0)

# %%
df['Awards Nominated For'] = df['Awards Nominated For'].replace(np.nan, 0)

# %%
df.isna().sum()
# Out:
# Title                       0
# Genre                       1
# Languages                   0
# Series or Movie             0
# Hidden Gem Score            0
# Country Availability        0
# Runtime                     0
# Director                    0
# Writer                      0
# Actors                      0
# IMDb Score                  0
# Rotten Tomatoes Score       0
# Awards Received             0
# Awards Nominated For        0
# Netflix Release Date        0
# Production House         2398
# IMDb Votes                  0
# dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.boxplot(data = df['IMDb Score'])
plt.title('Overall IMDb Score')
plt.show()

# %%
df.head(3)
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2     The Con-Heartist                         Comedy, Romance
#
#           Languages Series or Movie  Hidden Gem Score Country Availability  \
# 0  Swedish, Spanish          Series               4.3             Thailand
# 1           English           Movie               7.0               Canada
# 2              Thai           Movie               8.6             Thailand
#
#         Runtime         Director  \
# 0  < 30 minutes  Tomas Alfredson
# 1      1-2 hour    Coky Giedroyc
# 2       > 2 hrs    Mez Tharatorn
#
#                                               Writer  \
# 0                              John Ajvide Lindqvist
# 1                                      Caitlin Moran
# 2  Pattaranad Bhiboonsawade, Mez Tharatorn, Thods...
#
# ...

# %%
sns.boxplot(y=df['IMDb Score'], x=df['Series or Movie'])
plt.title('IMDb Score of Movies vs Series')
plt.xlabel(' ')
plt.show()

# %%
sns.boxenplot(data = df,
            x = df['Series or Movie'],
            y = df['IMDb Score'])
# Out:
# <Axes: xlabel='Series or Movie', ylabel='IMDb Score'>

# %%
sns.violinplot(data = df,
            x = df['Series or Movie'],
            y = df['IMDb Score'])
# Out:
# <Axes: xlabel='Series or Movie', ylabel='IMDb Score'>

# %%
sns.distplot(df['IMDb Score'])
plt.title('Histogram Plot For IMDb Score')
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2100\1059149096.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['IMDb Score'])

# %%
df['Main Genre'] = df['Genre'].apply(lambda x : str(x).split(','))

# %%
df['Main Genre 2'] = df['Main Genre'].apply(lambda x: x[0]) 
df
# Out:
#                             Title                                   Genre  \
# 0                Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1             HOW TO BUILD A GIRL                                  Comedy
# 2                The Con-Heartist                         Comedy, Romance
# 4                   Only a Mother                                   Drama
# 5                      Snowroller                                  Comedy
# ...                           ...                                     ...
# 9417                      4.3.2.1                         Crime, Thriller
# 9418                           13                  Crime, Drama, Thriller
# 9419       District 13: Ultimatum                 Action, Crime, Thriller
# 9420               13 Going on 30                Comedy, Fantasy, Romance
# 9423  Daniel Arends: Blessuretijd                                  Comedy
#
#                                 Languages Series or Movie  Hidden Gem Score  \
# ...

# %%
sns.barplot(y = df.groupby('Main Genre 2')['IMDb Score'].median().index, 
            x = df.groupby('Main Genre 2')['IMDb Score'].median().values, orient='h')
plt.ylabel(' ')
plt.show()

# %%
df['IMDb Score'].isnull().sum()
# Out:
# 0

# %%
sns.scatterplot(data = df['Rotten Tomatoes Score'])
# Out:
# <Axes: ylabel='Rotten Tomatoes Score'>

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
x = df.groupby('Languages')[['IMDb Score', 'Rotten Tomatoes Score']].mean()

# %%
x['Total Awards'] = df.groupby('Languages')['Awards Received'].sum()

# %%
x
# Out:
#                                            IMDb Score  Rotten Tomatoes Score  \
# Languages
# Afrikaans                                         6.8              64.139142
# Afrikaans, English                                6.6              70.000000
# Afrikaans, German, Swiss German                   7.5              64.139142
# Akan, English                                     6.5              64.139142
# Albanian, French                                  7.2              78.000000
# ...                                               ...                    ...
# Xhosa, Southern Sotho, English, Afrikaans         6.2              76.000000
# Yiddish, English, Spanish                         6.5              96.000000
# Zulu                                              7.2              64.139142
# Zulu, Afrikaans, Xhosa, English                   5.8              56.000000
# Zulu, Xhosa, Afrikaans, English                   7.2              82.000000
#
# ...

# %%
len(df.Runtime.unique())
# Out:
# 4

# %%
dff = df.groupby('Runtime')['Hidden Gem Score'].sum()

# %%
plt.pie(dff, labels=dff.index, autopct='%1.f%%', wedgeprops=dict(width=0.3))
plt.title('Hidden Gem Score vs Runtime')
plt.show()

# %%
dff
# Out:
# Runtime
# 1-2 hour        23152.5
# 30-60 mins        641.2
# < 30 minutes     1729.5
# > 2 hrs          7223.0
# Name: Hidden Gem Score, dtype: float64

# %%
sns.countplot(x = df.Runtime)
# Out:
# <Axes: xlabel='Runtime', ylabel='count'>

# %%
df['Country Availability'].sort_values()
df['Main Country'] = df['Country Availability'].apply(lambda x: str(x).split(','))
df['Main Country 2'] = df['Main Country'].apply(lambda x: x[0])
df.drop(['Main Country', 'Main Genre'], axis = 1, inplace = True)
df.rename(columns={'Main Country 2':'Main Country', 'Main Genre 2':'Main Genre'}, inplace = True)

# %%
df['Main Country'].unique()
# Out:
# array(['Thailand', 'Canada', 'Lithuania', 'Japan', 'South Korea',
#        'United Kingdom', 'Germany', 'France', 'Poland', 'Mexico',
#        'Netherlands', 'Brazil', 'South Africa', 'Singapore', 'Israel',
#        'Australia', 'United States', 'Russia', 'Romania', 'Italy',
#        'Colombia', 'Hong Kong', 'Sweden', 'Belgium', 'Czech Republic',
#        'India', 'Turkey', 'Argentina', 'Portugal', 'Iceland',
#        'Switzerland', 'Hungary', 'Spain', 'Slovakia', 'Greece',
#        'Malaysia'], dtype=object)

# %%
sns.countplot(y = df['Main Country'])
plt.title('Countrywise Movie Production')
plt.show()

# %%
df[['Title', 'IMDb Score']].sort_values('IMDb Score',ascending=False).head(10)
# Out:
#                                               Title  IMDb Score
# 8650                       The Shawshank Redemption         9.3
# 8724                                  The Godfather         9.2
# 4000                                The Consuls Son         9.1
# 1630                                       One Girl         9.1
# 3948                                 No Longer kids         9.0
# 8833                         The Godfather: Part II         9.0
# 8514                                The Dark Knight         9.0
# 9114  The Lord of the Rings: The Return of the King         8.9
# 9090                                   Pulp Fiction         8.9
# 8647                                Schindlers List         8.9

# %%
sns.barplot(data = df[['Title', 'IMDb Score']].sort_values('IMDb Score',ascending=False).head(10), 
            y = df[['Title', 'IMDb Score']].sort_values('IMDb Score',ascending=False).head(10)['Title'],
            x = df[['Title', 'IMDb Score']].sort_values('IMDb Score',ascending=False).head(10)['IMDb Score'])
plt.title('Top 10 Movies')
plt.show()

# %%
7/205926
# Out:
# 3.399279352777211e-05

# %%
7/2838
# Out:
# 0.0024665257223396757

# %%
df['Score per Votes'] = df['IMDb Score'] / df['IMDb Votes']

# %%
df['Score per Votes'].sort_values(ascending=False)
# Out:
# 7471    1.640000
# 1530    1.560000
# 413     1.383333
# 2771    1.366667
# 4556    1.366667
#           ...
# 511     0.000005
# 8713    0.000005
# 8381    0.000004
# 8650    0.000004
# 8514    0.000004
# Name: Score per Votes, Length: 6688, dtype: float64

# %%
sns.barplot(data = df[['Title', 'Score per Votes']].sort_values('Score per Votes').head(10),
            x = df[['Title', 'Score per Votes']].sort_values('Score per Votes').head(10)['Score per Votes'],
            y = df[['Title', 'Score per Votes']].sort_values('Score per Votes').head(10)['Title'])
plt.title('Best Movies Based on Population')
plt.show()

# %%
sns.barplot(data = df[['Title', 'Awards Received']].sort_values('Awards Received', ascending = False).head(10),
           x = df[['Title', 'Awards Received']].sort_values('Awards Received', ascending = False).head(10)['Awards Received'],
           y = df[['Title', 'Awards Received']].sort_values('Awards Received', ascending = False).head(10)['Title'])
plt.title('Most Awarded Movies')
plt.show()
